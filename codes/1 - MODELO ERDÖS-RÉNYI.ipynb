# %% [markdown]
# # IIC-3641 GML UC

# %% [markdown]
# - Versiones de librerías, python >= 3.10.2
#
# - networkx >= 2.6.2

# %% [markdown]
# # Grafos no dirigidos

# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node(4)
G.add_edge(1, 4)

# %%
G.number_of_nodes()
# Out:
# 4

# %%
G.number_of_edges()
# Out:
# 3

# %%
import matplotlib.pyplot as plt

nx.draw(G, with_labels=True, font_weight='bold')

# %%
G.remove_node(2)

# %% [markdown]
# # Grafos dirigidos

# %%
DG = nx.DiGraph()
DG.add_edge(2, 1)   
DG.add_edge(1, 3)
DG.add_edge(2, 4)

# %%
nx.draw(DG, with_labels=True, font_weight='bold')

# %% [markdown]
# # Nodos con atributos

# %%
G.add_node(1, time='5pm')
G.add_nodes_from([3], time='2pm')
G.nodes[1]
# Out:
# {'time': '5pm'}

# %% [markdown]
# # Enlaces con atributos

# %%
G.add_edge(1, 2, weight=4.7 )
G.add_edges_from([(3, 4), (4, 5)], color='red')
G.add_edges_from([(1, 2, {'color': 'blue'}), (2, 3, {'weight': 8})])
G[1][2]['weight'] = 4.7
G.edges[3, 4]['weight'] = 4.2

# %% [markdown]
# # Multigrafos

# %%
MG = nx.MultiGraph()
MG.add_weighted_edges_from([(1, 2, 0.5), (1, 2, 0.75), (2, 3, 0.5)])

# %% [markdown]
# # Operadores

# %%
G = nx.Graph([(0, 1), (0, 2), (1, 2)])
H = nx.Graph([(3, 4), (3, 5), (4, 5), (4, 6)])
U = nx.union(G, H, rename=("G", "H"))

# %%
nx.draw(U, with_labels=True, font_weight='bold')

# %%
U.add_edge('G1', 'H6')

# %%
nx.draw(U, with_labels=True, font_weight='bold')

# %%
G = nx.Graph([(0, 1), (0, 2)])
H = nx.Graph([(0, 1), (1, 2)])
R = nx.compose(G, H)

# %%
nx.draw(R, with_labels=True, font_weight='bold')

# %%
G = nx.Graph([(1, 2), (1, 3), (2, 3), (3, 4), (3, 5)])
G_complement = nx.complement(G)

# %%
nx.draw(G, with_labels=True, font_weight='bold')

# %%
nx.draw(G_complement, with_labels=True, font_weight='bold')

# %% [markdown]
# # Random networks

# %%
er = nx.erdos_renyi_graph(100, 0.07)

# %%
nx.draw(er, with_labels=True, font_weight='bold')

# %% [markdown]
# # Métricas

# %%
nx.clustering(er)
# Out:
# {0: 0.058333333333333334,
#  1: 0.07142857142857142,
#  2: 0.1388888888888889,
#  3: 0.047619047619047616,
#  4: 0.027777777777777776,
#  5: 0.14285714285714285,
#  6: 0.10256410256410256,
#  7: 0.06666666666666667,
#  8: 0.09523809523809523,
#  9: 0.16666666666666666,
#  10: 0.13333333333333333,
#  11: 0.16666666666666666,
#  12: 0.2,
#  13: 0.038461538461538464,
#  14: 0.14285714285714285,
#  15: 0.14285714285714285,
#  16: 0.05454545454545454,
#  17: 0,
#  18: 0.1388888888888889,
#  19: 0,
#  20: 0.14285714285714285,
#  21: 0.07272727272727272,
#  22: 0.17777777777777778,
#  23: 0.06666666666666667,
#  24: 0,
#  25: 0.08888888888888889,
#  26: 0,
#  27: 0.05555555555555555,
#  28: 0.09090909090909091,
#  29: 0.23809523809523808,
#  30: 0.10714285714285714,
#  31: 0.07142857142857142,
#  32: 0.10714285714285714,
#  33: 0.2,
#  34: 0.08333333333333333,
#  35: 0,
#  36: 0.09523809523809523,
#  37: 0.05555555555555555,
#  38: 0.07142857142857142,
#  39: 0.14285714285714285,
#  40: 0,
#  41: 0.15555555555555556,
#  42: 0,
#  43: 0,
#  44: 0.09523809523809523,
#  45: 0.14545454545454545,
#  46: 0,
#  47: 0.06666666666666667,
#  48: 0.09523809523809523,
#  49: 0.027777777777777776,
#  50: 0.3333333333333333,
#  51: 0.05555555555555555,
#  52: 0.06666666666666667,
#  53: 0,
#  54: 0.10714285714285714,
#  55: 0.05454545454545454,
#  56: 0.06666666666666667,
#  57: 0.1111111111111111,
#  58: 0.05454545454545454,
#  59: 0.14285714285714285,
#  60: 0.10714285714285714,
#  61: 0.13333333333333333,
#  62: 0.08333333333333333,
#  63: 0.13333333333333333,
#  64: 0.08333333333333333,
#  65: 0.16666666666666666,
#  66: 0.047619047619047616,
#  67: 0.2,
#  68: 0.1111111111111111,
#  69: 0.07142857142857142,
#  70: 0.09523809523809523,
#  71: 0.1282051282051282,
#  72: 0,
#  73: 0.10606060606060606,
#  74: 0.16666666666666666,
#  75: 0.16666666666666666,
#  76: 0.16666666666666666,
#  77: 0.054945054945054944,
#  78: 0.06666666666666667,
#  79: 0,
#  80: 0.19047619047619047,
#  81: 0.08333333333333333,
#  82: 0.1388888888888889,
#  83: 0.10606060606060606,
#  84: 0.06666666666666667,
#  85: 0.047619047619047616,
#  86: 0.07142857142857142,
#  87: 0.08333333333333333,
#  88: 0.09523809523809523,
#  89: 0.10909090909090909,
#  90: 0.13333333333333333,
#  91: 0.05555555555555555,
#  92: 0.13333333333333333,
#  93: 0.047619047619047616,
#  94: 0.047619047619047616,
#  95: 0.19047619047619047,
#  96: 0.13333333333333333,
#  97: 0.2,
#  98: 0.06666666666666667,
#  99: 0}

# %%
er.degree()
# Out:
# DegreeView({0: 16, 1: 8, 2: 9, 3: 7, 4: 9, 5: 8, 6: 13, 7: 6, 8: 7, 9: 4, 10: 10, 11: 4, 12: 6, 13: 13, 14: 8, 15: 7, 16: 11, 17: 3, 18: 9, 19: 5, 20: 8, 21: 11, 22: 10, 23: 10, 24: 3, 25: 10, 26: 4, 27: 9, 28: 12, 29: 7, 30: 8, 31: 8, 32: 8, 33: 6, 34: 9, 35: 7, 36: 7, 37: 9, 38: 8, 39: 7, 40: 4, 41: 10, 42: 4, 43: 6, 44: 7, 45: 11, 46: 6, 47: 6, 48: 7, 49: 9, 50: 4, 51: 9, 52: 6, 53: 7, 54: 8, 55: 11, 56: 10, 57: 9, 58: 11, 59: 7, 60: 8, 61: 6, 62: 9, 63: 6, 64: 9, 65: 9, 66: 7, 67: 5, 68: 9, 69: 8, 70: 7, 71: 13, 72: 9, 73: 12, 74: 4, 75: 4, 76: 9, 77: 14, 78: 6, 79: 5, 80: 7, 81: 9, 82: 9, 83: 12, 84: 6, 85: 7, 86: 8, 87: 9, 88: 7, 89: 11, 90: 6, 91: 9, 92: 6, 93: 7, 94: 7, 95: 7, 96: 10, 97: 5, 98: 10, 99: 3})

# %%
nx.diameter(er)
# Out:
# 4

# %% [markdown]
# # Distribución de grado

# %%
G = nx.erdos_renyi_graph(10000, 0.07)

degrees = [G.degree(n) for n in G.nodes()]

degree_counts = {}
for degree in degrees:
    if degree in degree_counts:
        degree_counts[degree] += 1
    else:
        degree_counts[degree] = 1

sorted_degrees = sorted(degree_counts.items())

x, y = zip(*sorted_degrees)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'bo-', markersize=7)
plt.title('Distribución de Grado')
plt.xlabel('Grado')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
