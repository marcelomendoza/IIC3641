# %% [markdown]
# # IIC-3641 GML UC

# %%
# !python3 -m pip list
# Out:
# WARNING: Ignoring invalid distribution -itsandbytes (/home/marcelo/.local/lib/python3.8/site-packages)
# Package                            Version
# ---------------------------------- -----------------------------------------
# absl-py                            1.1.0
# accelerate                         0.26.1
# aggdraw                            1.3.16
# aiohttp                            3.8.4
# aiosignal                          1.2.0
# alabaster                          0.7.12
# ann-visualizer                     2.5
# annotated-types                    0.6.0
# antlr4-python3-runtime             4.9.3
# anyio                              3.7.0
# AnyQt                              0.2.0
# anytree                            2.8.0
# appdirs                            1.4.4
# appnope                            0.1.3
# apturl                             0.5.2
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# array-record                       0.4.0
# arrow                              1.3.0
# astor                              0.8.1
# asttokens                          2.4.1
# astunparse                         1.6.3
# async-lru                          2.0.4
# async-timeout                      4.0.2
# attr                               0.3.2
# attrs                              23.1.0
# autograd                           1.4
# autograd-gamma                     0.5.0
# Automat                            22.10.0
# Babel                              2.10.1
# backcall                           0.2.0
# backoff                            2.2.1
# backports.functools-lru-cache      1.6.4
# backports.zoneinfo                 0.2.1
# baycomp                            1.0.2
# bcrypt                             3.1.7
# beautifulsoup4                     4.12.2
# binaryornot                        0.4.4
# biopython                          1.79
# bitsandbytes                       0.41.0
# bitsandbytes-cuda117               0.26.0.post2
# black                              23.3.0
# bleach                             6.0.0
# blinker                            1.4
# blis                               0.7.9
# boto3                              1.24.66
# boto3-stubs                        1.24.66
# botocore                           1.27.66
# botocore-stubs                     1.27.66
# botok                              0.8.8
# Bottleneck                         1.3.5
# bpe                                1.0
# bpemb                              0.3.4
# Brlapi                             0.7.0
# brminer                            0.0.3
# Brotli                             1.0.9
# brotlipy                           0.7.0
# bs4                                0.0.1
# build                              0.10.0
# CacheControl                       0.12.11
# cachetools                         5.2.0
# catalogue                          2.0.8
# cattrs                             22.1.0
# cchardet                           2.1.7
# certifi                            2019.11.28
# cffi                               1.15.1
# chardet                            3.0.4
# charset-normalizer                 3.1.0
# chex                               0.1.3
# chromadb                           0.3.22
# cleo                               2.0.1
# click                              8.1.3
# clickhouse-connect                 0.5.25
# cloudpathlib                       0.16.0
# cloudpickle                        2.1.0
# cmake                              3.29.3
# colorama                           0.4.3
# comm                               0.2.2
# command-not-found                  0.3
# commonmark                         0.9.1
# confection                         0.0.4
# configparser                       5.3.0
# conllu                             4.5.2
# constantly                         15.1.0
# contextlib2                        21.6.0
# cookiecutter                       2.6.0
# crashtest                          0.4.1
# crayons                            0.4.0
# crochet                            2.1.1
# cryptography                       41.0.1
# cssselect                          1.2.0
# cupshelpers                        1.0
# cycler                             0.11.0
# cymem                              2.0.7
# Cython                             0.28
# dataclasses                        0.6
# dataclasses-json                   0.5.7
# datasets                           2.16.1
# datefinder                         0.7.3
# dateparser                         1.1.8
# dbdemos                            0.3.13
# dbsqlclone                         0.1.21
# dbus-python                        1.2.16
# de-core-news-sm                    3.5.0
# debugpy                            1.6.7
# decorator                          5.1.1
# defer                              1.0.6
# defusedxml                         0.7.1
# dell-recovery                      0.0.0
# demjson3                           3.0.6
# Deprecated                         1.2.13
# dgl                                2.1.0
# dictdiffer                         0.9.0
# dill                               0.3.4
# distlib                            0.3.7
# distro                             1.9.0
# distro-info                        0.23+ubuntu1.1
# dm-tree                            0.1.7
# dnspython                          2.2.1
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.17.1
# docx2txt                           0.8
# duckdb                             0.8.0
# dulwich                            0.21.5
# duplicity                          0.8.12.0
# emoji                              1.7.0
# en-core-web-md                     3.5.0
# en-core-web-sm                     3.5.0
# entrypoints                        0.4
# es-core-news-lg                    3.5.0
# es-core-news-md                    3.5.0
# es-core-news-sm                    3.5.0
# et-xmlfile                         1.1.0
# etils                              1.3.0
# eval_type_backport                 0.2.0
# evaluate                           0.4.1
# exceptiongroup                     1.1.1
# executing                          2.0.1
# extruct                            0.14.0
# facebook-page-scraper              5.0.2
# facebook-scraper                   0.2.59
# fairseq                            0.10.2
# fake-useragent                     1.1.3
# fastapi                            0.95.2
# fastBPE                            0.1.1
# fasteners                          0.14.1
# fastjsonschema                     2.17.1
# fasttext                           0.9.2
# filelock                           3.12.2
# fishervector                       0.1
# flair                              0.12
# flatbuffers                        2.0
# flax                               0.5.0
# fonttools                          4.38.0
# formulaic                          0.5.0
# fqdn                               1.5.1
# frozenlist                         1.3.0
# fsspec                             2024.9.0
# ftfy                               6.1.1
# future                             0.18.2
# fuzzywuzzy                         0.18.0
# gast                               0.4.0
# gcsfs                              2023.5.0
# gdown                              4.4.0
# Genesis-PyAPI                      1.2.1
# gensim                             4.1.2
# gitdb                              4.0.10
# GitPython                          3.1.31
# google-api-core                    2.11.0
# google-auth                        2.29.0
# google-auth-oauthlib               1.0.0
# google-cloud-core                  2.3.2
# google-cloud-storage               2.7.0
# google-crc32c                      1.5.0
# google-pasta                       0.2.0
# google-resumable-media             2.4.1
# google-search-results              2.4.2
# googleapis-common-protos           1.56.2
# gpg                                1.13.1
# graphlib-backport                  1.0.3
# graphviz                           0.20.1
# greenlet                           1.0.0
# grpcio                             1.62.2
# h11                                0.14.0
# h2                                 4.1.0
# h5py                               3.7.0
# hdbscan                            0.8.33
# hnswlib                            0.7.0
# hpack                              4.0.0
# html-text                          0.5.2
# html5lib                           1.0.1
# httpcore                           1.0.5
# httplib2                           0.14.0
# httptools                          0.5.0
# httpx                              0.27.0
# huggingface-hub                    0.25.1
# humanize                           4.1.0
# hydra-core                         1.2.0
# hyperframe                         6.0.1
# hyperlink                          21.0.0
# hyperopt                           0.2.7
# hypothesis                         6.100.5
# idna                               3.4
# igraph                             0.9.11
# imageio                            2.19.3
# imagesize                          1.3.0
# imbalanced-learn                   0.11.0
# imblearn                           0.0
# importlib-metadata                 6.6.0
# importlib-resources                5.12.0
# incremental                        22.10.0
# indic-nlp-library                  0.81
# iniconfig                          2.0.0
# installer                          0.7.0
# instant-distance                   0.3.5
# interface-meta                     1.3.0
# ipykernel                          6.16.2
# ipympl                             0.9.3
# ipython                            7.34.0
# ipython_genutils                   0.2.0
# ipyvue                             1.11.1
# ipyvuetify                         1.9.4
# ipywidgets                         8.1.1
# isodate                            0.6.1
# isoduration                        20.11.0
# IsoScore                           1.0
# itemadapter                        0.8.0
# itemloaders                        1.1.0
# Janome                             0.4.2
# jaraco.classes                     3.2.2
# jax                                0.4.13
# jaxlib                             0.4.11
# jedi                               0.18.2
# jeepney                            0.8.0
# jellyfish                          0.9.0
# Jinja2                             3.1.2
# jmespath                           1.0.1
# joblib                             1.2.0
# json5                              0.9.25
# jsonpointer                        3.0.0
# jsonschema                         4.17.3
# jsonschema-specifications          2023.7.1
# jstyleson                          0.0.2
# jupyter_client                     7.4.9
# jupyter-console                    6.0.0
# jupyter_core                       4.12.0
# jupyter-events                     0.10.0
# jupyter-lsp                        2.2.5
# jupyter-server                     1.24.0
# jupyter_server_terminals           0.5.3
# jupyterlab                         4.2.4
# jupyterlab-pygments                0.2.2
# jupyterlab_server                  2.27.3
# jupyterlab_widgets                 3.0.13
# kaitaistruct                       0.10
# keras                              2.12.0
# keras-nightly                      2.11.0.dev2022080207
# Keras-Preprocessing                1.1.2
# keyring                            23.13.1
# keyrings.alt                       4.2.0
# khmer-nltk                         1.5
# kiwisolver                         1.4.4
# langchain                          0.0.164
# langcodes                          3.3.0
# langdetect                         1.0.9
# language-selector                  0.1
# LaoNLP                             0.6
# laserembeddings                    1.1.2
# launchpadlib                       1.10.13
# lazr.restfulclient                 0.14.2
# lazr.uri                           1.0.3
# lemmagen3                          3.3.2
# libclang                           14.0.1
# lifelines                          0.27.1
# lightning-utilities                0.11.7
# lime                               0.2.0.1
# lit                                18.1.4
# llvmlite                           0.38.1
# lockfile                           0.12.2
# loguru                             0.7.0
# loralib                            0.1.1
# louis                              3.12.0
# LTTL                               2.0.12
# lxml                               4.9.1
# lz4                                4.3.2
# macaroonbakery                     1.3.1
# Mako                               1.1.0
# Markdown                           3.3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         2.1.3
# marshmallow                        3.19.0
# marshmallow-enum                   1.5.1
# matplotlib                         3.5.3
# matplotlib-inline                  0.1.6
# mdurl                              0.1.2
# Mesa                               2.1.5
# Mesa-Viz-Tornado                   0.1.3
# mf2py                              1.1.2
# mistune                            2.0.5
# ml-dtypes                          0.2.0
# mock                               4.0.3
# monotonic                          1.5
# more-itertools                     4.2.0
# Morfessor                          2.0.6
# mpld3                              0.3
# mpmath                             1.3.0
# msgpack                            1.0.4
# multidict                          6.0.2
# multiprocess                       0.70.12.2
# murmurhash                         1.0.9
# mypy                               1.10.0
# mypy-boto3-s3                      1.24.36.post1
# mypy-extensions                    1.0.0
# nbclassic                          1.0.0
# nbclient                           0.7.4
# nbconvert                          7.4.0
# nbformat                           5.8.0
# ndf                                0.1.4
# nela-features                      3.0.1
# nest-asyncio                       1.5.6
# nested-lookup                      0.2.25
# netifaces                          0.10.4
# network-simulator                  1.0.0
# networkx                           2.8.3
# ninja                              1.11.1.1
# nltk                               3.4.5
# notebook                           6.5.4
# notebook_shim                      0.2.3
# numba                              0.55.2
# numexpr                            2.8.4
# numpy                              1.21.6
# nvidia-cublas-cu11                 11.10.3.66
# nvidia-cublas-cu12                 12.1.3.1
# nvidia-cuda-cupti-cu11             11.8.87
# nvidia-cuda-cupti-cu12             12.1.105
# nvidia-cuda-nvrtc-cu11             11.7.99
# nvidia-cuda-nvrtc-cu12             12.1.105
# nvidia-cuda-runtime-cu11           11.7.99
# nvidia-cuda-runtime-cu12           12.1.105
# nvidia-cudnn-cu11                  8.5.0.96
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cufft-cu11                  10.9.0.58
# nvidia-cufft-cu12                  11.0.2.54
# nvidia-curand-cu11                 10.3.0.86
# nvidia-curand-cu12                 10.3.2.106
# nvidia-cusolver-cu11               11.4.1.48
# nvidia-cusolver-cu12               11.4.5.107
# nvidia-cusparse-cu11               11.7.5.86
# nvidia-cusparse-cu12               12.1.0.106
# nvidia-nccl-cu11                   2.20.5
# nvidia-nccl-cu12                   2.19.3
# nvidia-nvjitlink-cu12              12.3.101
# nvidia-nvtx-cu11                   11.8.86
# nvidia-nvtx-cu12                   12.1.105
# oauthlib                           3.2.0
# odfpy                              1.4.1
# olefile                            0.46
# omegaconf                          2.2.2
# openai                             0.27.7
# openapi-schema-pydantic            1.2.4
# openpyxl                           3.0.10
# openTSNE                           0.6.2
# opt-einsum                         3.3.0
# optax                              0.1.2
# orange-canvas-core                 0.1.27
# orange-widget-base                 4.17.0
# Orange3                            3.32.0
# Orange3-Associate                  1.1.9
# Orange3-Bioinformatics             4.5.0
# Orange3-Educational                0.5.0
# Orange3-Explain                    0.6.0
# Orange3-Geo                        0.3.0
# Orange3-ImageAnalytics             0.8.0
# Orange3-Network                    1.7.0
# Orange3-Prototypes                 0.18.0
# Orange3-Survival-Analysis          0.4.0
# Orange3-Text                       1.11.0
# Orange3-Textable                   3.1.11
# Orange3-Timeseries                 0.5.1
# Orange3-WorldHappiness             0.1.8
# outcome                            1.2.0
# overrides                          7.7.0
# Owlready2                          0.38
# packaging                          23.1
# pandas                             1.3.5
# pandas-datareader                  0.10.0
# pandocfilters                      1.5.0
# paramiko                           2.6.0
# parse                              1.19.1
# parsel                             1.8.1
# parso                              0.8.3
# pathspec                           0.11.1
# pathtools                          0.1.2
# pathy                              0.10.1
# patsy                              0.5.2
# pdfminer3k                         1.3.4
# peft                               0.7.2.dev0
# pexpect                            4.8.0
# pgmpy                              0.1.25
# pickleshare                        0.7.5
# Pillow                             9.5.0
# pip                                24.2
# pkginfo                            1.9.6
# pkgutil_resolve_name               1.3.10
# platformdirs                       3.6.0
# playwright                         1.9.0
# plotly                             5.9.0
# pluggy                             1.5.0
# ply                                3.11
# poetry                             1.5.1
# poetry-core                        1.6.1
# poetry-plugin-export               1.4.0
# point-annotator                    2.0.0
# portalocker                        2.4.0
# posthog                            3.0.1
# powerlaw                           1.5
# pptree                             3.1
# preshed                            3.0.8
# progressbar                        2.5
# prometheus-client                  0.17.0
# promise                            2.3
# prompt-toolkit                     3.0.38
# Protego                            0.2.1
# protobuf                           3.20.3
# psutil                             5.9.5
# ptyprocess                         0.7.0
# pure_eval                          0.2.3
# py-readability-metrics             1.4.5
# py4j                               0.10.9.7
# pyamg                              4.2.3
# pyarrow                            8.0.0
# pyarrow-hotfix                     0.6
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pybind11                           2.10.0
# pycairo                            1.16.2
# pyclipper                          1.3.0.post3
# pycountry                          22.3.5
# pycparser                          2.21
# pycups                             1.9.73
# pydantic                           1.10.8
# pydantic_core                      2.23.4
# PyDispatcher                       2.0.7
# pyee                               9.0.4
# pyenchant                          3.2.2
# pyg-lib                            0.4.0+pt20cu117
# Pygments                           2.15.1
# PyGObject                          3.36.0
# PyJWT                              1.7.1
# pymacaroons                        0.13.0
# pymongo                            4.2.0
# PyNaCl                             1.3.0
# pynndescent                        0.5.8
# pyOpenSSL                          23.2.0
# pyparsing                          3.0.9
# pyppeteer                          1.0.2
# pyproject_hooks                    1.0.0
# PyQt5                              5.15.7
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.11.0
# pyqtgraph                          0.12.3
# PyQtWebEngine                      5.15.6
# PyQtWebEngine-Qt5                  5.15.2
# pyquery                            2.0.0
# pyRdfa3                            3.5.3
# pyRFC3339                          1.1
# pyrsistent                         0.19.3
# pysentimiento                      0.7.2
# PySocks                            1.7.1
# pyspark                            3.4.0
# PyTDC                              0.4.0
# pytest                             8.2.0
# pythainlp                          3.0.8
# python-apt                         2.0.1+ubuntu0.20.4.1
# python-crfsuite                    0.9.8
# python-dateutil                    2.8.2
# python-debian                      0.1.36+ubuntu1.1
# python-dotenv                      1.0.0
# python-json-logger                 2.0.7
# python-louvain                     0.16
# python-slugify                     8.0.4
# pytorch-pretrained-bert            0.6.2
# pytorch_revgrad                    0.2.0
# pytorch-transformers               1.2.0
# pytz                               2023.3
# pytz-deprecation-shim              0.1.0.post0
# PyWavelets                         1.3.0
# pyxdg                              0.26
# PyYAML                             6.0
# pyzmq                              25.1.0
# qasync                             0.23.0
# qtconsole                          5.3.2
# QtPy                               2.2.0
# queuelib                           1.6.2
# rank-bm25                          0.2.2
# rapidfuzz                          2.15.1
# rdflib                             6.3.2
# rdkit                              2023.3.1
# rdkit-pypi                         2022.9.5
# reacton                            1.8.3
# referencing                        0.30.0
# regex                              2022.4.24
# reportlab                          3.5.34
# requests                           2.31.0
# requests-cache                     0.9.6
# requests-file                      1.5.1
# requests-html                      0.10.0
# requests-oauthlib                  1.3.1
# requests-toolbelt                  1.0.0
# requests-unixsocket                0.2.0
# resdk                              15.0.0
# responses                          0.18.0
# rfc3339-validator                  0.1.4
# rfc3986                            1.5.0
# rfc3986-validator                  0.1.1
# rich                               13.7.1
# rich-click                         1.8.3
# rpds-py                            0.9.2
# rsa                                4.8
# s3transfer                         0.6.0
# sacrebleu                          2.1.0
# sacremoses                         0.0.35
# safetensors                        0.4.3
# SALib                              1.4.8
# schema                             0.7.5
# scikit-dimension                   0.3
# scikit-image                       0.15.0
# scikit-learn                       1.0.2
# scipy                              1.7.3
# scrapfly-sdk                       0.8.6
# Scrapy                             2.9.0
# screen-resolution-extra            0.0.0
# seaborn                            0.12.2
# SecretStorage                      3.3.3
# segtok                             1.5.11
# selenium                           4.1.0
# selenium-wire                      5.1.0
# semantic-version                   2.10.0
# Send2Trash                         1.8.2
# sentence-cleaner-splitter          1.0.1
# sentence-splitter                  1.4
# sentence-transformers              2.2.2
# sentencepiece                      0.1.97
# sentry-sdk                         1.21.0
# serverfiles                        0.3.1
# service-identity                   23.1.0
# setproctitle                       1.3.2
# setuptools                         69.2.0
# shap                               0.40.0
# Shapely                            1.8.4
# shellingham                        1.5.0.post1
# shtab                              1.7.1
# simhash                            2.1.2
# simplejson                         3.16.0
# six                                1.16.0
# sklearn                            0.0
# sklearn-crfsuite                   0.3.6
# slicer                             0.0.7
# slumber                            0.7.1
# smart-open                         6.0.0
# smmap                              5.0.0
# sniffio                            1.3.0
# snowballstemmer                    2.2.0
# soil                               0.20.7
# solara                             1.36.0
# solara-server                      1.36.0
# solara-ui                          1.36.0
# sortedcontainers                   2.4.0
# sos                                4.5.6
# soupsieve                          2.4.1
# spacy                              3.5.1
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.4
# Sphinx                             5.0.1
# sphinx-argparse                    0.3.1
# sphinx-rtd-theme                   1.0.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# SQLAlchemy                         1.4.37
# SQLAlchemy-Utils                   0.38.2
# sqlitedict                         2.1.0
# srsly                              2.4.6
# stack-data                         0.6.3
# starlette                          0.27.0
# statsmodels                        0.13.2
# stellar                            0.4.5
# subword-nmt                        0.3.8
# sympy                              1.12
# systemd-python                     234
# tabulate                           0.8.9
# tenacity                           8.2.2
# tensorboard                        2.12.3
# tensorboard-data-server            0.7.2
# tensorboard-plugin-wit             1.8.1
# tensorboardX                       1.9
# tensorflow                         2.12.1
# tensorflow-datasets                4.9.2
# tensorflow-estimator               2.12.0
# tensorflow-examples                907a3e7466aa72345c983b596cba58b255f2b1f7-
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.26.0
# tensorflow-metadata                1.8.0
# tensorflow-text                    2.12.0
# termcolor                          1.1.0
# terminado                          0.17.1
# testpath                           0.4.4
# text-unidecode                     1.3
# texttable                          1.6.4
# tf-estimator-nightly               2.10.0.dev2022060908
# tf-keras                           2.15.0
# tf-nightly                         2.11.0.dev20220802
# tfds-nightly                       4.9.2.dev202308090034
# Theano                             1.0.5
# thinc                              8.1.9
# threadpoolctl                      3.1.0
# tifffile                           2022.5.4
# tiktoken                           0.3.3
# timestring                         1.6.4
# tinycss2                           1.2.1
# tinydb                             4.7.0
# tldextract                         3.4.4
# tokenizers                         0.15.2
# toml                               0.10.2
# tomli                              2.0.1
# tomlkit                            0.11.8
# toolz                              0.11.2
# torch                              2.4.1+cu118
# torch-cluster                      1.6.3+pt20cu117
# torch-geometric                    2.6.1
# torch-scatter                      2.1.2+pt20cu117
# torch-sparse                       0.6.18+pt20cu117
# torch-spline-conv                  1.2.2+pt20cu117
# torchaudio                         0.13.1
# torchdata                          0.7.1
# torchinfo                          1.8.0
# torchmetrics                       0.11.4
# torchtext                          0.8.0
# torchvision                        0.14.1
# tornado                            6.2
# tqdm                               4.65.0
# traitlets                          5.9.0
# transformer-smaller-training-vocab 0.2.3
# transformers                       4.36.2
# transliterate                      1.10.2
# treetaggerwrapper                  2.3
# trio                               0.22.1
# trio-websocket                     0.10.3
# triton                             2.1.0
# trl                                0.7.11.dev0
# trove-classifiers                  2023.7.6
# tsih                               0.1.9
# tweepy                             4.10.1
# Twisted                            22.10.0
# typed-ast                          1.5.4
# typer                              0.7.0
# types-awscrt                       0.14.5
# types-python-dateutil              2.9.0.20240316
# types-s3transfer                   0.6.0.post4
# typing_extensions                  4.6.3
# typing-inspect                     0.9.0
# tyro                               0.8.4
# tzdata                             2022.2
# tzlocal                            4.2
# ubuntu-drivers-common              0.0.0
# ubuntu-pro-client                  8001
# ufal.udpipe                        1.2.0.3
# ufw                                0.36
# umap-learn                         0.5.3
# unattended-upgrades                0.1
# uri-template                       1.3.0
# url-normalize                      1.4.3
# urllib3                            1.26.20
# urllib3-secure-extra               0.1.0
# usb-creator                        0.3.7
# uvicorn                            0.22.0
# uvloop                             0.17.0
# vaderSentiment                     3.3.2
# versioneer                         0.28
# virtualenv                         20.24.0
# visualkeras                        0.0.2
# w3lib                              2.1.1
# wadllib                            1.3.3
# wandb                              0.15.0
# wasabi                             1.1.1
# watchdog                           4.0.1
# watchfiles                         0.19.0
# wbgapi                             1.0.12
# wcwidth                            0.2.6
# weasel                             0.3.4
# webcolors                          24.8.0
# webdriver-manager                  3.2.2
# webencodings                       0.5.1
# websocket-client                   1.5.2
# websockets                         10.4
# wefe                               0.3.2
# weightwatcher                      0.7.1.5
# Werkzeug                           2.1.2
# wheel                              0.43.0
# widgetsnbextension                 4.0.13
# wikipedia                          1.4.0
# Wikipedia-API                      0.5.8
# wrapt                              1.14.1
# wsproto                            1.2.0
# xkit                               0.0.0
# xlrd                               2.0.1
# XlsxWriter                         3.0.3
# xxhash                             3.0.0
# yake                               0.4.8
# yarl                               1.7.2
# zipp                               3.15.0
# zope.interface                     6.0
# zstandard                          0.21.0

# %%
import torch
print(torch.__version__)

device = torch.device('cuda')
# Out:
# 2.4.1+cu118

# %%
import os
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch.nn import BatchNorm1d as BN
from torch.nn import Linear, ReLU, Sequential
from torch.optim import Adam
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GINConv, global_mean_pool
from torch_geometric.utils import degree
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN2at4_ops10zeros_like4callERKNS_6TensorEN3c108optionalINS5_10ScalarTypeEEENS6_INS5_6LayoutEEENS6_INS5_6DeviceEEENS6_IbEENS6_INS5_12MemoryFormatEEE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# /home/marcelo/.local/lib/python3.8/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# ## Vamos a trabajar con una dataset de Reddit para clasificación binaria de grafos

# %%
dataset = TUDataset("data/", "REDDIT-BINARY", cleaned=False)
dataset.data.edge_attr = None
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %% [markdown]
# ### Referencia a datasets de TUDataset: https://grlplus.github.io/papers/79.pdf
#
# ### Ver documentación de los datasets en: https://pytorch-geometric.readthedocs.io/en/latest/generated/torch_geometric.datasets.TUDataset.html

# %% [markdown]
# ## Aquí va una función de normalización de grado

# %%
class NormalizedDegree:
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, data):
        deg = degree(data.edge_index[0], dtype=torch.float)
        deg = (deg - self.mean) / self.std
        data.x = deg.view(-1, 1)
        return data

# %% [markdown]
# ## Se usa one hot para los X, usando el grado del nodo, ya que el dataset no tiene X

# %%
if dataset.data.x is None:
    max_degree = 0
    degs = []
    for data in dataset:
        degs += [degree(data.edge_index[0], dtype=torch.long)]
        max_degree = max(max_degree, degs[-1].max().item())

    print(max_degree)

    if max_degree < 1000:
        dataset.transform = T.OneHotDegree(max_degree)
    else:
        deg = torch.cat(degs, dim=0).to(torch.float)
        mean, std = deg.mean().item(), deg.std().item()
        dataset.transform = NormalizedDegree(mean, std)
# Out:
# 3062

# %%
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
def num_graphs(data):
    if hasattr(data, "num_graphs"):
        return data.num_graphs
    else:
        return data.x.size(0)

# %% [markdown]
# ## Se define el modelo GIN

# %%
class GIN0(torch.nn.Module):
    def __init__(self, dataset, num_layers, hidden):
        super().__init__()
        self.conv1 = GINConv(
            Sequential(
                Linear(dataset.num_features, hidden),
                ReLU(),
                Linear(hidden, hidden),
                ReLU(),
                BN(hidden),
            ),
            train_eps=False,
        )
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(
                GINConv(
                    Sequential(
                        Linear(hidden, hidden),
                        ReLU(),
                        Linear(hidden, hidden),
                        ReLU(),
                        BN(hidden),
                    ),
                    train_eps=False,
                )
            )
        self.lin1 = Linear(hidden, hidden)
        self.lin2 = Linear(hidden, dataset.num_classes)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        for conv in self.convs:
            conv.reset_parameters()
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = self.conv1(x, edge_index)
        for conv in self.convs:
            x = conv(x, edge_index)
        x = global_mean_pool(x, batch)
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


# model = GIN0(dataset, config.num_layers, config.latent_dim)
model = GIN0(dataset, 5, 32)

# %% [markdown]
# ## Se definen los ciclos de training y evaluación

# %%
def train(model, optimizer, loader):
    model.train()

    total_loss = 0
    for data in loader:
        optimizer.zero_grad()
        data = data.to(device)
        out = model(data)
        loss = F.nll_loss(out, data.y.view(-1))
        loss.backward()
        total_loss += loss.item() * num_graphs(data)
        optimizer.step()
    return total_loss / len(loader.dataset)


def eval(model, loader):
    model.eval()

    correct = 0
    for data in loader:
        data = data.to(device)
        with torch.no_grad():
            pred = model(data).max(1)[1]
        correct += pred.eq(data.y.view(-1)).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ## Optimizer y entrenamiento

# %%
model.to(device).reset_parameters()
optimizer = Adam(model.parameters(), lr=0.01)

for epoch in range(1, 50 + 1):
    train_loss = train(model, optimizer, train_loader)
    train_acc = eval(model, train_loader)
    print("Epoch:", epoch,"Training Loss: ", train_loss, "Training Acc: ", train_acc)
# Out:
# Epoch: 1 Training Loss:  0.581225879907608 Training Acc:  0.6855
# Epoch: 2 Training Loss:  0.5407945499420166 Training Acc:  0.7655
# Epoch: 3 Training Loss:  0.4885126895904541 Training Acc:  0.7725
# Epoch: 4 Training Loss:  0.47090305578708647 Training Acc:  0.784
# Epoch: 5 Training Loss:  0.44570968961715696 Training Acc:  0.836
# Epoch: 6 Training Loss:  0.4549015798568726 Training Acc:  0.798
# Epoch: 7 Training Loss:  0.43515063667297366 Training Acc:  0.7615
# Epoch: 8 Training Loss:  0.46540514516830445 Training Acc:  0.7115
# Epoch: 9 Training Loss:  0.40907820510864257 Training Acc:  0.831
# Epoch: 10 Training Loss:  0.4171438689231873 Training Acc:  0.702
# Epoch: 11 Training Loss:  0.45854467010498046 Training Acc:  0.803
# Epoch: 12 Training Loss:  0.4493528497219086 Training Acc:  0.8495
# Epoch: 13 Training Loss:  0.43879363012313843 Training Acc:  0.719
# Epoch: 14 Training Loss:  0.38880557572841645 Training Acc:  0.8
# Epoch: 15 Training Loss:  0.37944952273368837 Training Acc:  0.8125
# Epoch: 16 Training Loss:  0.36631717085838317 Training Acc:  0.8165
# Epoch: 17 Training Loss:  0.35594156074523925 Training Acc:  0.851
# Epoch: 18 Training Loss:  0.38739781045913696 Training Acc:  0.861
# Epoch: 19 Training Loss:  0.3864284381866455 Training Acc:  0.5825
# Epoch: 20 Training Loss:  0.37370324683189393 Training Acc:  0.832
# Epoch: 21 Training Loss:  0.414084658741951 Training Acc:  0.794
# Epoch: 22 Training Loss:  0.41116414380073546 Training Acc:  0.55
# Epoch: 23 Training Loss:  0.3922769067287445 Training Acc:  0.7075
# Epoch: 24 Training Loss:  0.38110812962055207 Training Acc:  0.8435
# Epoch: 25 Training Loss:  0.35313734436035155 Training Acc:  0.5385
# Epoch: 26 Training Loss:  0.4842016323804855 Training Acc:  0.579
# Epoch: 27 Training Loss:  0.4520578145980835 Training Acc:  0.735
# Epoch: 28 Training Loss:  0.4050093173980713 Training Acc:  0.636
# Epoch: 29 Training Loss:  0.4122412023544312 Training Acc:  0.8565
# Epoch: 30 Training Loss:  0.3678553879261017 Training Acc:  0.861
# Epoch: 31 Training Loss:  0.3712147970199585 Training Acc:  0.8205
# Epoch: 32 Training Loss:  0.37515850687026975 Training Acc:  0.6205
# Epoch: 33 Training Loss:  0.43724920964241026 Training Acc:  0.8485
# Epoch: 34 Training Loss:  0.40836554646492007 Training Acc:  0.722
# Epoch: 35 Training Loss:  0.44280283665657044 Training Acc:  0.778
# Epoch: 36 Training Loss:  0.406185107588768 Training Acc:  0.8445
# Epoch: 37 Training Loss:  0.38111454057693483 Training Acc:  0.7905
# Epoch: 38 Training Loss:  0.3723332394361496 Training Acc:  0.876
# Epoch: 39 Training Loss:  0.36129154539108277 Training Acc:  0.7915
# Epoch: 40 Training Loss:  0.3799779176712036 Training Acc:  0.857
# Epoch: 41 Training Loss:  0.3441940360069275 Training Acc:  0.87
# Epoch: 42 Training Loss:  0.34474070692062375 Training Acc:  0.801
# Epoch: 43 Training Loss:  0.36787729930877683 Training Acc:  0.8905
# Epoch: 44 Training Loss:  0.3354492702484131 Training Acc:  0.8695
# Epoch: 45 Training Loss:  0.35551336216926577 Training Acc:  0.8885
# Epoch: 46 Training Loss:  0.33543773531913756 Training Acc:  0.8675
# Epoch: 47 Training Loss:  0.33357740092277527 Training Acc:  0.8955
# Epoch: 48 Training Loss:  0.32355632042884824 Training Acc:  0.863
# Epoch: 49 Training Loss:  0.33523300290107727 Training Acc:  0.743
# Epoch: 50 Training Loss:  0.3612929491996765 Training Acc:  0.873
