# %% [markdown]
# # IIC-3641 GML UC

# %%
# !python3 -m pip list
# Out:
# WARNING: Ignoring invalid distribution -itsandbytes (/home/marcelo/.local/lib/python3.8/site-packages)
# Package                            Version
# ---------------------------------- -----------------------------------------
# absl-py                            1.1.0
# accelerate                         0.26.1
# aggdraw                            1.3.16
# aiohttp                            3.8.4
# aiosignal                          1.2.0
# alabaster                          0.7.12
# ann-visualizer                     2.5
# annotated-types                    0.6.0
# antlr4-python3-runtime             4.9.3
# anyio                              3.7.0
# AnyQt                              0.2.0
# anytree                            2.8.0
# appdirs                            1.4.4
# appnope                            0.1.3
# apturl                             0.5.2
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# array-record                       0.4.0
# arrow                              1.3.0
# astor                              0.8.1
# asttokens                          2.4.1
# astunparse                         1.6.3
# async-lru                          2.0.4
# async-timeout                      4.0.2
# attr                               0.3.2
# attrs                              23.1.0
# autograd                           1.4
# autograd-gamma                     0.5.0
# Automat                            22.10.0
# Babel                              2.10.1
# backcall                           0.2.0
# backoff                            2.2.1
# backports.functools-lru-cache      1.6.4
# backports.zoneinfo                 0.2.1
# baycomp                            1.0.2
# bcrypt                             3.1.7
# beautifulsoup4                     4.12.2
# binaryornot                        0.4.4
# biopython                          1.79
# bitsandbytes                       0.41.0
# bitsandbytes-cuda117               0.26.0.post2
# black                              23.3.0
# bleach                             6.0.0
# blinker                            1.4
# blis                               0.7.9
# boto3                              1.24.66
# boto3-stubs                        1.24.66
# botocore                           1.27.66
# botocore-stubs                     1.27.66
# botok                              0.8.8
# Bottleneck                         1.3.5
# bpe                                1.0
# bpemb                              0.3.4
# Brlapi                             0.7.0
# brminer                            0.0.3
# Brotli                             1.0.9
# brotlipy                           0.7.0
# bs4                                0.0.1
# build                              0.10.0
# CacheControl                       0.12.11
# cachetools                         5.2.0
# catalogue                          2.0.8
# cattrs                             22.1.0
# cchardet                           2.1.7
# certifi                            2019.11.28
# cffi                               1.15.1
# chardet                            3.0.4
# charset-normalizer                 3.1.0
# chex                               0.1.3
# chromadb                           0.3.22
# cleo                               2.0.1
# click                              8.1.3
# clickhouse-connect                 0.5.25
# cloudpathlib                       0.16.0
# cloudpickle                        2.1.0
# cmake                              3.29.3
# colorama                           0.4.3
# comm                               0.2.2
# command-not-found                  0.3
# commonmark                         0.9.1
# confection                         0.0.4
# configparser                       5.3.0
# conllu                             4.5.2
# constantly                         15.1.0
# contextlib2                        21.6.0
# cookiecutter                       2.6.0
# crashtest                          0.4.1
# crayons                            0.4.0
# crochet                            2.1.1
# cryptography                       41.0.1
# cssselect                          1.2.0
# cupshelpers                        1.0
# cycler                             0.11.0
# cymem                              2.0.7
# Cython                             0.28
# dataclasses                        0.6
# dataclasses-json                   0.5.7
# datasets                           2.16.1
# datefinder                         0.7.3
# dateparser                         1.1.8
# dbdemos                            0.3.13
# dbsqlclone                         0.1.21
# dbus-python                        1.2.16
# de-core-news-sm                    3.5.0
# debugpy                            1.6.7
# decorator                          5.1.1
# defer                              1.0.6
# defusedxml                         0.7.1
# dell-recovery                      0.0.0
# demjson3                           3.0.6
# Deprecated                         1.2.13
# dgl                                2.1.0
# dictdiffer                         0.9.0
# dill                               0.3.4
# distlib                            0.3.7
# distro                             1.9.0
# distro-info                        0.23+ubuntu1.1
# dm-tree                            0.1.7
# dnspython                          2.2.1
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.17.1
# docx2txt                           0.8
# duckdb                             0.8.0
# dulwich                            0.21.5
# duplicity                          0.8.12.0
# emoji                              1.7.0
# en-core-web-md                     3.5.0
# en-core-web-sm                     3.5.0
# entrypoints                        0.4
# es-core-news-lg                    3.5.0
# es-core-news-md                    3.5.0
# es-core-news-sm                    3.5.0
# et-xmlfile                         1.1.0
# etils                              1.3.0
# eval_type_backport                 0.2.0
# evaluate                           0.4.1
# exceptiongroup                     1.1.1
# executing                          2.0.1
# extruct                            0.14.0
# facebook-page-scraper              5.0.2
# facebook-scraper                   0.2.59
# fairseq                            0.10.2
# fake-useragent                     1.1.3
# fastapi                            0.95.2
# fastBPE                            0.1.1
# fasteners                          0.14.1
# fastjsonschema                     2.17.1
# fasttext                           0.9.2
# filelock                           3.12.2
# fishervector                       0.1
# flair                              0.12
# flatbuffers                        2.0
# flax                               0.5.0
# fonttools                          4.38.0
# formulaic                          0.5.0
# fqdn                               1.5.1
# frozenlist                         1.3.0
# fsspec                             2024.9.0
# ftfy                               6.1.1
# future                             0.18.2
# fuzzywuzzy                         0.18.0
# gast                               0.4.0
# gcsfs                              2023.5.0
# gdown                              4.4.0
# Genesis-PyAPI                      1.2.1
# gensim                             4.1.2
# gitdb                              4.0.10
# GitPython                          3.1.31
# google-api-core                    2.11.0
# google-auth                        2.29.0
# google-auth-oauthlib               1.0.0
# google-cloud-core                  2.3.2
# google-cloud-storage               2.7.0
# google-crc32c                      1.5.0
# google-pasta                       0.2.0
# google-resumable-media             2.4.1
# google-search-results              2.4.2
# googleapis-common-protos           1.56.2
# gpg                                1.13.1
# graphlib-backport                  1.0.3
# graphviz                           0.20.1
# greenlet                           1.0.0
# grpcio                             1.62.2
# h11                                0.14.0
# h2                                 4.1.0
# h5py                               3.7.0
# hdbscan                            0.8.33
# hnswlib                            0.7.0
# hpack                              4.0.0
# html-text                          0.5.2
# html5lib                           1.0.1
# httpcore                           1.0.5
# httplib2                           0.14.0
# httptools                          0.5.0
# httpx                              0.27.0
# huggingface-hub                    0.25.1
# humanize                           4.1.0
# hydra-core                         1.2.0
# hyperframe                         6.0.1
# hyperlink                          21.0.0
# hyperopt                           0.2.7
# hypothesis                         6.100.5
# idna                               3.4
# igraph                             0.9.11
# imageio                            2.19.3
# imagesize                          1.3.0
# imbalanced-learn                   0.11.0
# imblearn                           0.0
# importlib-metadata                 6.6.0
# importlib-resources                5.12.0
# incremental                        22.10.0
# indic-nlp-library                  0.81
# iniconfig                          2.0.0
# installer                          0.7.0
# instant-distance                   0.3.5
# interface-meta                     1.3.0
# ipykernel                          6.16.2
# ipympl                             0.9.3
# ipython                            7.34.0
# ipython_genutils                   0.2.0
# ipyvue                             1.11.1
# ipyvuetify                         1.9.4
# ipywidgets                         8.1.1
# isodate                            0.6.1
# isoduration                        20.11.0
# IsoScore                           1.0
# itemadapter                        0.8.0
# itemloaders                        1.1.0
# Janome                             0.4.2
# jaraco.classes                     3.2.2
# jax                                0.4.13
# jaxlib                             0.4.11
# jedi                               0.18.2
# jeepney                            0.8.0
# jellyfish                          0.9.0
# Jinja2                             3.1.2
# jmespath                           1.0.1
# joblib                             1.2.0
# json5                              0.9.25
# jsonpointer                        3.0.0
# jsonschema                         4.17.3
# jsonschema-specifications          2023.7.1
# jstyleson                          0.0.2
# jupyter_client                     7.4.9
# jupyter-console                    6.0.0
# jupyter_core                       4.12.0
# jupyter-events                     0.10.0
# jupyter-lsp                        2.2.5
# jupyter-server                     1.24.0
# jupyter_server_terminals           0.5.3
# jupyterlab                         4.2.4
# jupyterlab-pygments                0.2.2
# jupyterlab_server                  2.27.3
# jupyterlab_widgets                 3.0.13
# kaitaistruct                       0.10
# keras                              2.12.0
# keras-nightly                      2.11.0.dev2022080207
# Keras-Preprocessing                1.1.2
# keyring                            23.13.1
# keyrings.alt                       4.2.0
# khmer-nltk                         1.5
# kiwisolver                         1.4.4
# langchain                          0.0.164
# langcodes                          3.3.0
# langdetect                         1.0.9
# language-selector                  0.1
# LaoNLP                             0.6
# laserembeddings                    1.1.2
# launchpadlib                       1.10.13
# lazr.restfulclient                 0.14.2
# lazr.uri                           1.0.3
# lemmagen3                          3.3.2
# libclang                           14.0.1
# lifelines                          0.27.1
# lightning-utilities                0.11.7
# lime                               0.2.0.1
# lit                                18.1.4
# llvmlite                           0.38.1
# lockfile                           0.12.2
# loguru                             0.7.0
# loralib                            0.1.1
# louis                              3.12.0
# LTTL                               2.0.12
# lxml                               4.9.1
# lz4                                4.3.2
# macaroonbakery                     1.3.1
# Mako                               1.1.0
# Markdown                           3.3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         2.1.3
# marshmallow                        3.19.0
# marshmallow-enum                   1.5.1
# matplotlib                         3.5.3
# matplotlib-inline                  0.1.6
# mdurl                              0.1.2
# Mesa                               2.1.5
# Mesa-Viz-Tornado                   0.1.3
# mf2py                              1.1.2
# mistune                            2.0.5
# ml-dtypes                          0.2.0
# mock                               4.0.3
# monotonic                          1.5
# more-itertools                     4.2.0
# Morfessor                          2.0.6
# mpld3                              0.3
# mpmath                             1.3.0
# msgpack                            1.0.4
# multidict                          6.0.2
# multiprocess                       0.70.12.2
# murmurhash                         1.0.9
# mypy                               1.10.0
# mypy-boto3-s3                      1.24.36.post1
# mypy-extensions                    1.0.0
# nbclassic                          1.0.0
# nbclient                           0.7.4
# nbconvert                          7.4.0
# nbformat                           5.8.0
# ndf                                0.1.4
# nela-features                      3.0.1
# nest-asyncio                       1.5.6
# nested-lookup                      0.2.25
# netifaces                          0.10.4
# network-simulator                  1.0.0
# networkx                           2.8.3
# ninja                              1.11.1.1
# nltk                               3.4.5
# notebook                           6.5.4
# notebook_shim                      0.2.3
# numba                              0.55.2
# numexpr                            2.8.4
# numpy                              1.21.6
# nvidia-cublas-cu11                 11.10.3.66
# nvidia-cublas-cu12                 12.1.3.1
# nvidia-cuda-cupti-cu11             11.8.87
# nvidia-cuda-cupti-cu12             12.1.105
# nvidia-cuda-nvrtc-cu11             11.7.99
# nvidia-cuda-nvrtc-cu12             12.1.105
# nvidia-cuda-runtime-cu11           11.7.99
# nvidia-cuda-runtime-cu12           12.1.105
# nvidia-cudnn-cu11                  8.5.0.96
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cufft-cu11                  10.9.0.58
# nvidia-cufft-cu12                  11.0.2.54
# nvidia-curand-cu11                 10.3.0.86
# nvidia-curand-cu12                 10.3.2.106
# nvidia-cusolver-cu11               11.4.1.48
# nvidia-cusolver-cu12               11.4.5.107
# nvidia-cusparse-cu11               11.7.5.86
# nvidia-cusparse-cu12               12.1.0.106
# nvidia-nccl-cu11                   2.20.5
# nvidia-nccl-cu12                   2.19.3
# nvidia-nvjitlink-cu12              12.3.101
# nvidia-nvtx-cu11                   11.8.86
# nvidia-nvtx-cu12                   12.1.105
# oauthlib                           3.2.0
# odfpy                              1.4.1
# olefile                            0.46
# omegaconf                          2.2.2
# openai                             0.27.7
# openapi-schema-pydantic            1.2.4
# openpyxl                           3.0.10
# openTSNE                           0.6.2
# opt-einsum                         3.3.0
# optax                              0.1.2
# orange-canvas-core                 0.1.27
# orange-widget-base                 4.17.0
# Orange3                            3.32.0
# Orange3-Associate                  1.1.9
# Orange3-Bioinformatics             4.5.0
# Orange3-Educational                0.5.0
# Orange3-Explain                    0.6.0
# Orange3-Geo                        0.3.0
# Orange3-ImageAnalytics             0.8.0
# Orange3-Network                    1.7.0
# Orange3-Prototypes                 0.18.0
# Orange3-Survival-Analysis          0.4.0
# Orange3-Text                       1.11.0
# Orange3-Textable                   3.1.11
# Orange3-Timeseries                 0.5.1
# Orange3-WorldHappiness             0.1.8
# outcome                            1.2.0
# overrides                          7.7.0
# Owlready2                          0.38
# packaging                          23.1
# pandas                             1.3.5
# pandas-datareader                  0.10.0
# pandocfilters                      1.5.0
# paramiko                           2.6.0
# parse                              1.19.1
# parsel                             1.8.1
# parso                              0.8.3
# pathspec                           0.11.1
# pathtools                          0.1.2
# pathy                              0.10.1
# patsy                              0.5.2
# pdfminer3k                         1.3.4
# peft                               0.7.2.dev0
# pexpect                            4.8.0
# pgmpy                              0.1.25
# pickleshare                        0.7.5
# Pillow                             9.5.0
# pip                                24.2
# pkginfo                            1.9.6
# pkgutil_resolve_name               1.3.10
# platformdirs                       3.6.0
# playwright                         1.9.0
# plotly                             5.9.0
# pluggy                             1.5.0
# ply                                3.11
# poetry                             1.5.1
# poetry-core                        1.6.1
# poetry-plugin-export               1.4.0
# point-annotator                    2.0.0
# portalocker                        2.4.0
# posthog                            3.0.1
# powerlaw                           1.5
# pptree                             3.1
# preshed                            3.0.8
# progressbar                        2.5
# prometheus-client                  0.17.0
# promise                            2.3
# prompt-toolkit                     3.0.38
# Protego                            0.2.1
# protobuf                           3.20.3
# psutil                             5.9.5
# ptyprocess                         0.7.0
# pure_eval                          0.2.3
# py-readability-metrics             1.4.5
# py4j                               0.10.9.7
# pyamg                              4.2.3
# pyarrow                            8.0.0
# pyarrow-hotfix                     0.6
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pybind11                           2.10.0
# pycairo                            1.16.2
# pyclipper                          1.3.0.post3
# pycountry                          22.3.5
# pycparser                          2.21
# pycups                             1.9.73
# pydantic                           1.10.8
# pydantic_core                      2.23.4
# PyDispatcher                       2.0.7
# pyee                               9.0.4
# pyenchant                          3.2.2
# pyg-lib                            0.4.0+pt20cu117
# Pygments                           2.15.1
# PyGObject                          3.36.0
# PyJWT                              1.7.1
# pymacaroons                        0.13.0
# pymongo                            4.2.0
# PyNaCl                             1.3.0
# pynndescent                        0.5.8
# pyOpenSSL                          23.2.0
# pyparsing                          3.0.9
# pyppeteer                          1.0.2
# pyproject_hooks                    1.0.0
# PyQt5                              5.15.7
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.11.0
# pyqtgraph                          0.12.3
# PyQtWebEngine                      5.15.6
# PyQtWebEngine-Qt5                  5.15.2
# pyquery                            2.0.0
# pyRdfa3                            3.5.3
# pyRFC3339                          1.1
# pyrsistent                         0.19.3
# pysentimiento                      0.7.2
# PySocks                            1.7.1
# pyspark                            3.4.0
# PyTDC                              0.4.0
# pytest                             8.2.0
# pythainlp                          3.0.8
# python-apt                         2.0.1+ubuntu0.20.4.1
# python-crfsuite                    0.9.8
# python-dateutil                    2.8.2
# python-debian                      0.1.36+ubuntu1.1
# python-dotenv                      1.0.0
# python-json-logger                 2.0.7
# python-louvain                     0.16
# python-slugify                     8.0.4
# pytorch-pretrained-bert            0.6.2
# pytorch_revgrad                    0.2.0
# pytorch-transformers               1.2.0
# pytz                               2023.3
# pytz-deprecation-shim              0.1.0.post0
# PyWavelets                         1.3.0
# pyxdg                              0.26
# PyYAML                             6.0
# pyzmq                              25.1.0
# qasync                             0.23.0
# qtconsole                          5.3.2
# QtPy                               2.2.0
# queuelib                           1.6.2
# rank-bm25                          0.2.2
# rapidfuzz                          2.15.1
# rdflib                             6.3.2
# rdkit                              2023.3.1
# rdkit-pypi                         2022.9.5
# reacton                            1.8.3
# referencing                        0.30.0
# regex                              2022.4.24
# reportlab                          3.5.34
# requests                           2.31.0
# requests-cache                     0.9.6
# requests-file                      1.5.1
# requests-html                      0.10.0
# requests-oauthlib                  1.3.1
# requests-toolbelt                  1.0.0
# requests-unixsocket                0.2.0
# resdk                              15.0.0
# responses                          0.18.0
# rfc3339-validator                  0.1.4
# rfc3986                            1.5.0
# rfc3986-validator                  0.1.1
# rich                               13.7.1
# rich-click                         1.8.3
# rpds-py                            0.9.2
# rsa                                4.8
# s3transfer                         0.6.0
# sacrebleu                          2.1.0
# sacremoses                         0.0.35
# safetensors                        0.4.3
# SALib                              1.4.8
# schema                             0.7.5
# scikit-dimension                   0.3
# scikit-image                       0.15.0
# scikit-learn                       1.0.2
# scipy                              1.7.3
# scrapfly-sdk                       0.8.6
# Scrapy                             2.9.0
# screen-resolution-extra            0.0.0
# seaborn                            0.12.2
# SecretStorage                      3.3.3
# segtok                             1.5.11
# selenium                           4.1.0
# selenium-wire                      5.1.0
# semantic-version                   2.10.0
# Send2Trash                         1.8.2
# sentence-cleaner-splitter          1.0.1
# sentence-splitter                  1.4
# sentence-transformers              2.2.2
# sentencepiece                      0.1.97
# sentry-sdk                         1.21.0
# serverfiles                        0.3.1
# service-identity                   23.1.0
# setproctitle                       1.3.2
# setuptools                         69.2.0
# shap                               0.40.0
# Shapely                            1.8.4
# shellingham                        1.5.0.post1
# shtab                              1.7.1
# simhash                            2.1.2
# simplejson                         3.16.0
# six                                1.16.0
# sklearn                            0.0
# sklearn-crfsuite                   0.3.6
# slicer                             0.0.7
# slumber                            0.7.1
# smart-open                         6.0.0
# smmap                              5.0.0
# sniffio                            1.3.0
# snowballstemmer                    2.2.0
# soil                               0.20.7
# solara                             1.36.0
# solara-server                      1.36.0
# solara-ui                          1.36.0
# sortedcontainers                   2.4.0
# sos                                4.5.6
# soupsieve                          2.4.1
# spacy                              3.5.1
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.4
# Sphinx                             5.0.1
# sphinx-argparse                    0.3.1
# sphinx-rtd-theme                   1.0.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# SQLAlchemy                         1.4.37
# SQLAlchemy-Utils                   0.38.2
# sqlitedict                         2.1.0
# srsly                              2.4.6
# stack-data                         0.6.3
# starlette                          0.27.0
# statsmodels                        0.13.2
# stellar                            0.4.5
# subword-nmt                        0.3.8
# sympy                              1.12
# systemd-python                     234
# tabulate                           0.8.9
# tenacity                           8.2.2
# tensorboard                        2.12.3
# tensorboard-data-server            0.7.2
# tensorboard-plugin-wit             1.8.1
# tensorboardX                       1.9
# tensorflow                         2.12.1
# tensorflow-datasets                4.9.2
# tensorflow-estimator               2.12.0
# tensorflow-examples                907a3e7466aa72345c983b596cba58b255f2b1f7-
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.26.0
# tensorflow-metadata                1.8.0
# tensorflow-text                    2.12.0
# termcolor                          1.1.0
# terminado                          0.17.1
# testpath                           0.4.4
# text-unidecode                     1.3
# texttable                          1.6.4
# tf-estimator-nightly               2.10.0.dev2022060908
# tf-keras                           2.15.0
# tf-nightly                         2.11.0.dev20220802
# tfds-nightly                       4.9.2.dev202308090034
# Theano                             1.0.5
# thinc                              8.1.9
# threadpoolctl                      3.1.0
# tifffile                           2022.5.4
# tiktoken                           0.3.3
# timestring                         1.6.4
# tinycss2                           1.2.1
# tinydb                             4.7.0
# tldextract                         3.4.4
# tokenizers                         0.15.2
# toml                               0.10.2
# tomli                              2.0.1
# tomlkit                            0.11.8
# toolz                              0.11.2
# torch                              2.4.1+cu118
# torch-cluster                      1.6.3+pt20cu117
# torch-geometric                    2.6.1
# torch-scatter                      2.1.2+pt20cu117
# torch-sparse                       0.6.18+pt20cu117
# torch-spline-conv                  1.2.2+pt20cu117
# torchaudio                         0.13.1
# torchdata                          0.7.1
# torchinfo                          1.8.0
# torchmetrics                       0.11.4
# torchtext                          0.8.0
# torchvision                        0.14.1
# tornado                            6.2
# tqdm                               4.65.0
# traitlets                          5.9.0
# transformer-smaller-training-vocab 0.2.3
# transformers                       4.36.2
# transliterate                      1.10.2
# treetaggerwrapper                  2.3
# trio                               0.22.1
# trio-websocket                     0.10.3
# triton                             2.1.0
# trl                                0.7.11.dev0
# trove-classifiers                  2023.7.6
# tsih                               0.1.9
# tweepy                             4.10.1
# Twisted                            22.10.0
# typed-ast                          1.5.4
# typer                              0.7.0
# types-awscrt                       0.14.5
# types-python-dateutil              2.9.0.20240316
# types-s3transfer                   0.6.0.post4
# typing_extensions                  4.6.3
# typing-inspect                     0.9.0
# tyro                               0.8.4
# tzdata                             2022.2
# tzlocal                            4.2
# ubuntu-drivers-common              0.0.0
# ubuntu-pro-client                  8001
# ufal.udpipe                        1.2.0.3
# ufw                                0.36
# umap-learn                         0.5.3
# unattended-upgrades                0.1
# uri-template                       1.3.0
# url-normalize                      1.4.3
# urllib3                            1.26.20
# urllib3-secure-extra               0.1.0
# usb-creator                        0.3.7
# uvicorn                            0.22.0
# uvloop                             0.17.0
# vaderSentiment                     3.3.2
# versioneer                         0.28
# virtualenv                         20.24.0
# visualkeras                        0.0.2
# w3lib                              2.1.1
# wadllib                            1.3.3
# wandb                              0.15.0
# wasabi                             1.1.1
# watchdog                           4.0.1
# watchfiles                         0.19.0
# wbgapi                             1.0.12
# wcwidth                            0.2.6
# weasel                             0.3.4
# webcolors                          24.8.0
# webdriver-manager                  3.2.2
# webencodings                       0.5.1
# websocket-client                   1.5.2
# websockets                         10.4
# wefe                               0.3.2
# weightwatcher                      0.7.1.5
# Werkzeug                           2.1.2
# wheel                              0.43.0
# widgetsnbextension                 4.0.13
# wikipedia                          1.4.0
# Wikipedia-API                      0.5.8
# wrapt                              1.14.1
# wsproto                            1.2.0
# xkit                               0.0.0
# xlrd                               2.0.1
# XlsxWriter                         3.0.3
# xxhash                             3.0.0
# yake                               0.4.8
# yarl                               1.7.2
# zipp                               3.15.0
# zope.interface                     6.0
# zstandard                          0.21.0

# %%
import torch
print(torch.__version__)

device = torch.device('cuda')
# Out:
# 2.4.1+cu118

# %% [markdown]
# #!git clone https://github.com/pgniewko/gt-pyg.git (ver en el repo el archivo environment.yml para dependencias)

# %% [markdown]
# ## En este ejemplo usaremos teorch geometric

# %%
from torch_geometric.data import Data
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN2at4_ops10zeros_like4callERKNS_6TensorEN3c108optionalINS5_10ScalarTypeEEENS6_INS5_6LayoutEEENS6_INS5_6DeviceEEENS6_IbEENS6_INS5_12MemoryFormatEEE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(
# /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/marcelo/.local/lib/python3.8/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# /home/marcelo/.local/lib/python3.8/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# ## El layer de GT lo importamos desde el proyecto gt_pyg

# %%
from gt_pyg.gt_pyg.nn.gt_conv import GTConv

# %% [markdown]
# ## Aquí importamos el RDKit

# %%
# Standard
import logging
import importlib

# Third party
import numpy as np
import rdkit
from rdkit import RDLogger
import torch
from torch import nn
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch_geometric.loader import DataLoader

# %% [markdown]
# ## Usamos torchmetric para trabajar con MAE

# %%
import torchmetrics
from torchmetrics import MeanAbsoluteError
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# /home/marcelo/.local/lib/python3.8/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/marcelo/.local/lib/python3.8/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %%
import gt_pyg.gt_pyg

# %% [markdown]
# ## Vamos a usar el GT con edge features

# %%
from gt_pyg.gt_pyg.data.utils import (
    get_tensor_data, 
    get_node_dim, 
    get_edge_dim, 
    get_train_valid_test_data
)
from gt_pyg.gt_pyg.nn.model import GraphTransformerNet

# %%
# Turn off majority of RDKit warnings
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)


# Set a random seed for a reproducibility purposes
# torch.manual_seed(192837465)

# Setup the logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Log the used versions of RDkit and torch
print(f'Numpy version: {np.__version__}')
print(f'Rdkit version: {rdkit.__version__}')
print(f'Torch version: {torch.__version__}')
print(f'TorchMetrics version: {torchmetrics.__version__}')
# Out:
# Numpy version: 1.21.6
# Rdkit version: 2023.03.1
# Torch version: 2.4.1+cu118
# TorchMetrics version: 0.11.4

# %% [markdown]
# ## Desde tdc importamos el benchmark de ADMET

# %%
from tdc import utils
names = utils.retrieve_benchmark_names('ADMET_Group')
output = "\n".join([f"{index}. {name}" for index, name in enumerate(names, start=1)])
print("Available endpoints:\n\n" + output)
# Out:
# Available endpoints:
#
# 1. caco2_wang
# 2. hia_hou
# 3. pgp_broccatelli
# 4. bioavailability_ma
# 5. lipophilicity_astrazeneca
# 6. solubility_aqsoldb
# 7. bbb_martins
# 8. ppbr_az
# 9. vdss_lombardo
# 10. cyp2d6_veith
# 11. cyp3a4_veith
# 12. cyp2c9_veith
# 13. cyp2d6_substrate_carbonmangels
# 14. cyp3a4_substrate_carbonmangels
# 15. cyp2c9_substrate_carbonmangels
# 16. half_life_obach
# 17. clearance_microsome_az
# 18. clearance_hepatocyte_az
# 19. herg
# 20. ames
# 21. dili
# 22. ld50_zhu

# %% [markdown]
# ## Vamos a trabajar con moléculas generadas por el laboratorio Astrazeneca

# %%
PE_DIM = 6 
(tr, va, te) = get_train_valid_test_data('lipophilicity_astrazeneca', min_num_atoms=0)
tr_dataset = get_tensor_data(tr.Drug.to_list(), tr.Y.to_list(), pe_dim=PE_DIM)
va_dataset = get_tensor_data(va.Drug.to_list(), va.Y.to_list(), pe_dim=PE_DIM)
te_dataset = get_tensor_data(te.Drug.to_list(), te.Y.to_list(), pe_dim=PE_DIM)
NODE_DIM = get_node_dim()
EDGE_DIM = get_edge_dim()

print(f'Number of training examples: {len(tr_dataset)}')
print(f'Number of validation examples: {len(va_dataset)}')
print(f'Number of test examples: {len(te_dataset)}')

train_loader = DataLoader(tr_dataset, batch_size=64)
val_loader = DataLoader(va_dataset, batch_size=512)
test_loader = DataLoader(te_dataset, batch_size=512)
# Out:
# Found local copy...
# Loading...
# Done!
# Processing data: 0it [00:00, ?it/s]
# Processing data: 0it [00:00, ?it/s]
# Processing data: 0it [00:00, ?it/s]
# Processing data: 0it [00:00, ?it/s]
# Processing data: 0it [00:00, ?it/s]
# Number of training examples: 2940
# Number of validation examples: 420
# Number of test examples: 840

# %%
print(f'Node dim: {NODE_DIM}')
print(f'Edge dim: {EDGE_DIM}')
# Out:
# Node dim: 76
# Edge dim: 10

# %% [markdown]
# ## La función de pérdida es L1 (diferencia absoluta) alineada con el error MAE

# %%
def train(epoch, loss_func):
    model.train()
    train_mae = MeanAbsoluteError().to(device)

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        
        # randomly flip sign of eigenvectors
        
        #device = data.pe.device  # Get the device of data.pe
        batch_pe = data.pe * (2 * torch.randint(low=0, high=2, size=(1, PE_DIM), device=device).float() - 1.0)
        #batch_pe = data.pe * (2 * torch.randint(low=0, high=2, size=(1, PE_DIM)).float() - 1.0)
        (out,_) = model(data.x, data.edge_index, data.edge_attr, batch_pe, data.batch, zero_var=False)
        loss = loss_func(out.squeeze(), data.y)
        loss.backward()
        optimizer.step()
        
        train_mae.update(out.squeeze(), data.y)

    return train_mae.compute()


@torch.no_grad()
def test(loader):
    model.eval()
    test_mae = MeanAbsoluteError().to(device)

    total_error = 0
    for data in loader:
        data = data.to(device)
        # randomly flip sign of eigenvectors
        batch_pe = data.pe * (2 * torch.randint(low=0, high=2, size=(1, PE_DIM), device=device).float() - 1.0)
        (out,_) = model(data.x, data.edge_index, data.edge_attr, batch_pe, data.batch)
        
        test_mae.update(out.squeeze(), data.y)
        
    return test_mae.compute()

train_loss = nn.L1Loss(reduction='mean')

# %% [markdown]
# ## Aquí dimensionamos al GT. Son 4 capas y 8 heads.

# %%
from torch_geometric import *

import torch._dynamo
torch._dynamo.config.suppress_errors = True

device = torch.device('cuda')

model = GraphTransformerNet(node_dim_in=NODE_DIM,
                            edge_dim_in=EDGE_DIM,
                            pe_in_dim=PE_DIM,
                            num_gt_layers=4, 
                            hidden_dim=128,
                            num_heads=8,
                            norm='bn',
                            gate=False,
                            qkv_bias=False,
                            gt_aggregators=['sum'],
                            aggregators=['sum'],
                            dropout=0.1,
                            act='relu').to(device)

if int(torch.__version__.split('.')[0]) >= 2:
    model = torch_geometric.compile(model) 

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10,
                              min_lr=0.00001)

print(model)
print(f"Number of params: {model.num_parameters()//1000} k")
# Out:
# OptimizedModule(
#   (_orig_mod): GraphTransformerNet(
#     (node_emb): Linear(in_features=76, out_features=128, bias=False)
#     (edge_emb): Linear(in_features=10, out_features=128, bias=False)
#     (pe_emb): Linear(in_features=6, out_features=128, bias=False)
#     (gt_layers): ModuleList(
#       (0-3): 4 x GTConv(128, 128, heads=8, aggrs: sum, qkv_bias: False, gate: False)
#     )
#     (global_pool): MultiAggregation([
#       SumAggregation(),
#     ], mode=cat)
#     (mu_mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (log_var_mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )
# Number of params: 708 k

# %%
best_epoch = 0
best_validation_loss = np.inf
test_set_mae = np.inf

# %% [markdown]
# ## El loop de entrenamiento informa sobre MAE en Val y Test

# %%
for epoch in range(1, 51):
    tr_loss = train(epoch, loss_func=train_loss)
    va_loss = test(val_loader)
    te_loss = test(test_loader)
    scheduler.step(va_loss)
    print(f'Epoch: {epoch:02d}, Loss: {tr_loss:.4f}, Val: {va_loss:.4f}, '
          f'Test: {te_loss:.4f}')
    if va_loss < best_validation_loss:
        best_epoch = epoch
        best_validation_loss = va_loss
        test_set_mae = te_loss
        
print("\nModel's performance on the test set\n"
        "===================================\n"
        f'MAE={test_set_mae}\n'
        f'Epoch={best_epoch}')
# Out:
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0] Graph break from `Tensor.item()`, consider setting:
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0]     torch._dynamo.config.capture_scalar_outputs = True
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0] or:
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0]     env TORCHDYNAMO_CAPTURE_SCALAR_OUTPUTS=1
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0] to include these operations in the captured graph.
# W1008 10:20:48.094755 140382441187136 torch/_dynamo/variables/tensor.py:715] [1/0]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] WON'T CONVERT forward /home/marcelo/Dropbox/Codes_STGO/IIC-3641/Codes 2024/gt_pyg/gt_pyg/nn/gt_conv.py line 143
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] due to:
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 497, in wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return handle_graph_break(self, inst, speculation.reason)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 566, in handle_graph_break
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(self, reason=reason)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 290, in aot_dispatch_autograd
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     fw_module, bw_module = aot_config.partition_fn(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1437, in partition_fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     _recursive_joint_graph_passes(graph)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 256, in _recursive_joint_graph_passes
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     joint_graph_passes(gm)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/joint_graph.py", line 326, in joint_graph_passes
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     count += patterns.apply(graph.graph)  # type: ignore[arg-type]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/pattern_matcher.py", line 1698, in apply
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     if is_match(m) and entry.extra_check(m):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/pattern_matcher.py", line 1314, in check_fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     if is_match(specific_pattern_match) and extra_check(specific_pattern_match):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 502, in should_pad_mm
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return should_pad_common(mat1, mat2) and should_pad_bench(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 367, in should_pad_bench
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     cached_pad = get_cached_should_pad(key)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 233, in get_cached_should_pad
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return get_pad_cache().lookup(key)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 229, in get_pad_cache
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return torch._inductor.codecache.LocalCache()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codecache.py", line 189, in __init__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.system = CacheBase.get_system()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codecache.py", line 143, in get_system
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 497, in wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return handle_graph_break(self, inst, speculation.reason)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 566, in handle_graph_break
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(self, reason=reason)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 290, in aot_dispatch_autograd
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     fw_module, bw_module = aot_config.partition_fn(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1437, in partition_fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     _recursive_joint_graph_passes(graph)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 256, in _recursive_joint_graph_passes
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     joint_graph_passes(gm)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/joint_graph.py", line 326, in joint_graph_passes
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     count += patterns.apply(graph.graph)  # type: ignore[arg-type]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/pattern_matcher.py", line 1698, in apply
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     if is_match(m) and entry.extra_check(m):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/pattern_matcher.py", line 1314, in check_fn
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     if is_match(specific_pattern_match) and extra_check(specific_pattern_match):
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 502, in should_pad_mm
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return should_pad_common(mat1, mat2) and should_pad_bench(
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 367, in should_pad_bench
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     cached_pad = get_cached_should_pad(key)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 233, in get_cached_should_pad
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return get_pad_cache().lookup(key)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/fx_passes/pad_mm.py", line 229, in get_pad_cache
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     return torch._inductor.codecache.LocalCache()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codecache.py", line 189, in __init__
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.system = CacheBase.get_system()
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codecache.py", line 143, in get_system
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:20:48.369405 140382441187136 torch/_dynamo/convert_frame.py:1009]
# Uncaught exception in compile_worker subprocess
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_worker/__main__.py", line 38, in main
#     pre_fork_setup()
#   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/async_compile.py", line 62, in pre_fork_setup
#     from triton.compiler.compiler import triton_key
# ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] WON'T CONVERT propagate /tmp/gt_pyg.gt_pyg.nn.gt_conv_GTConv_propagate_tp56l8ft.py line 176
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] due to:
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 497, in wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return handle_graph_break(self, inst, speculation.reason)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 566, in handle_graph_break
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(self, reason=reason)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 461, in aot_dispatch_autograd
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1640, in codegen
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.scheduler.codegen()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/scheduler.py", line 2741, in codegen
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.get_backend(device).codegen_node(node)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/cuda_combined_scheduling.py", line 69, in codegen_node
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self._triton_scheduling.codegen_node(node)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1148, in codegen_node
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.codegen_node_schedule(node_schedule, buf_accesses, numel, rnumel)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1317, in codegen_node_schedule
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     src_code = kernel.codegen_kernel()
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2159, in codegen_kernel
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     **self.inductor_meta_common(),
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2047, in inductor_meta_common
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     "backend_hash": torch.utils._triton.triton_hash_with_backend(),
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/utils/_triton.py", line 61, in triton_hash_with_backend
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:20:48.798929 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# ...
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 461, in aot_dispatch_autograd
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1640, in codegen
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.scheduler.codegen()
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/scheduler.py", line 2741, in codegen
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.get_backend(device).codegen_node(node)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/cuda_combined_scheduling.py", line 69, in codegen_node
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self._triton_scheduling.codegen_node(node)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1148, in codegen_node
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.codegen_node_schedule(node_schedule, buf_accesses, numel, rnumel)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1317, in codegen_node_schedule
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     src_code = kernel.codegen_kernel()
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2159, in codegen_kernel
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     **self.inductor_meta_common(),
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2047, in inductor_meta_common
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     "backend_hash": torch.utils._triton.triton_hash_with_backend(),
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/utils/_triton.py", line 61, in triton_hash_with_backend
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:20:50.445326 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:20:52.947504 140382441187136 torch/_dynamo/convert_frame.py:762] [15/8] torch._dynamo hit config.cache_size_limit (8)
# W1008 10:20:52.947504 140382441187136 torch/_dynamo/convert_frame.py:762] [15/8]    function: 'broadcast' (/home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/utils/_scatter.py:192)
# W1008 10:20:52.947504 140382441187136 torch/_dynamo/convert_frame.py:762] [15/8]    last reason: GLOBAL_STATE changed: grad_mode
# W1008 10:20:52.947504 140382441187136 torch/_dynamo/convert_frame.py:762] [15/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W1008 10:20:52.947504 140382441187136 torch/_dynamo/convert_frame.py:762] [15/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html.
# Epoch: 01, Loss: 1.7570, Val: 1.0077, Test: 1.0874
# Epoch: 02, Loss: 1.0890, Val: 1.2647, Test: 1.3239
# Epoch: 03, Loss: 1.0871, Val: 1.1578, Test: 1.2477
# Epoch: 04, Loss: 1.0192, Val: 1.3667, Test: 1.4846
# Epoch: 05, Loss: 1.0192, Val: 1.4004, Test: 1.5476
# Epoch: 06, Loss: 1.0206, Val: 1.3003, Test: 1.4099
# Epoch: 07, Loss: 0.9904, Val: 1.4159, Test: 1.5717
# Epoch: 08, Loss: 0.9686, Val: 1.4100, Test: 1.5118
# Epoch: 09, Loss: 0.9460, Val: 1.4998, Test: 1.6702
# Epoch: 10, Loss: 0.9498, Val: 1.3408, Test: 1.5183
# Epoch: 11, Loss: 0.9561, Val: 1.0133, Test: 1.0819
# Epoch: 12, Loss: 0.9360, Val: 1.1705, Test: 1.2673
# Epoch: 13, Loss: 0.9065, Val: 0.9536, Test: 1.0161
# Epoch: 14, Loss: 0.8917, Val: 1.0989, Test: 1.1874
# Epoch: 15, Loss: 0.8982, Val: 1.0818, Test: 1.1732
# Epoch: 16, Loss: 0.8928, Val: 1.1501, Test: 1.2565
# Epoch: 17, Loss: 0.8872, Val: 0.9683, Test: 1.0651
# Epoch: 18, Loss: 0.8709, Val: 0.8999, Test: 0.9702
# Epoch: 19, Loss: 0.8717, Val: 1.1634, Test: 1.3168
# Epoch: 20, Loss: 0.8613, Val: 1.3137, Test: 1.4453
# Epoch: 21, Loss: 0.8626, Val: 1.1870, Test: 1.3141
# Epoch: 22, Loss: 0.8470, Val: 1.2139, Test: 1.3562
# Epoch: 23, Loss: 0.8366, Val: 1.1751, Test: 1.2948
# Epoch: 24, Loss: 0.8263, Val: 1.2635, Test: 1.4122
# Epoch: 25, Loss: 0.8193, Val: 1.3347, Test: 1.4738
# Epoch: 26, Loss: 0.8061, Val: 0.8590, Test: 0.8899
# Epoch: 27, Loss: 0.8048, Val: 0.9477, Test: 1.0286
# Epoch: 28, Loss: 0.7856, Val: 1.1209, Test: 1.2309
# Epoch: 29, Loss: 0.7780, Val: 0.7838, Test: 0.8459
# Epoch: 30, Loss: 0.7846, Val: 1.6296, Test: 1.7721
# Epoch: 31, Loss: 0.7748, Val: 1.0817, Test: 1.2268
# Epoch: 32, Loss: 0.7389, Val: 0.8071, Test: 0.8971
# Epoch: 33, Loss: 0.7405, Val: 0.8284, Test: 0.9228
# Epoch: 34, Loss: 0.7397, Val: 2.4982, Test: 2.6825
# Epoch: 35, Loss: 0.7287, Val: 3.1630, Test: 3.4444
# Epoch: 36, Loss: 0.7029, Val: 0.7753, Test: 0.8538
# Epoch: 37, Loss: 0.6929, Val: 0.7572, Test: 0.8290
# Epoch: 38, Loss: 0.6928, Val: 0.8414, Test: 0.9277
# Epoch: 39, Loss: 0.6768, Val: 1.5542, Test: 1.6995
# Epoch: 40, Loss: 0.6616, Val: 1.1300, Test: 1.2353
# Epoch: 41, Loss: 0.6690, Val: 1.5708, Test: 1.6817
# Epoch: 42, Loss: 0.6326, Val: 0.8010, Test: 0.8319
# Epoch: 43, Loss: 0.6356, Val: 1.0234, Test: 1.1433
# Epoch: 44, Loss: 0.6295, Val: 0.6744, Test: 0.7567
# Epoch: 45, Loss: 0.6190, Val: 0.7675, Test: 0.7779
# Epoch: 46, Loss: 0.6051, Val: 0.7320, Test: 0.7482
# Epoch: 47, Loss: 0.5958, Val: 0.6658, Test: 0.7183
# Epoch: 48, Loss: 0.5848, Val: 1.1467, Test: 1.2339
# Epoch: 49, Loss: 0.5769, Val: 1.0807, Test: 1.1094
# Epoch: 50, Loss: 0.5741, Val: 0.7559, Test: 0.8063
#
# Model's performance on the test set
# ===================================
# MAE=0.7182777523994446
# Epoch=47

# %% [markdown]
# ## Aquí una variante que cambia la función de activación

# %%
model = GraphTransformerNet(node_dim_in=NODE_DIM,
                            edge_dim_in=EDGE_DIM,
                            pe_in_dim=PE_DIM,
                            num_gt_layers=4, 
                            hidden_dim=128,
                            num_heads=8,
                            norm='bn',
                            gt_aggregators=['sum', "mean"],
                            aggregators=['sum','mean','max', 'std'],
                            dropout=0.1,
                            act='gelu').to(device)

if int(torch.__version__.split('.')[0]) >= 2:
    model = torch_geometric.compile(model) 

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10,
                              min_lr=0.00001)

print(model)
print(f"Number of params: {model.num_parameters()//1000} k")


best_epoch = 0
best_validation_loss = np.inf
test_set_mae = np.inf
for epoch in range(1, 51):
    tr_loss = train(epoch, loss_func=train_loss)
    va_loss = test(val_loader)
    te_loss = test(test_loader)
    scheduler.step(va_loss)
    print(f'Epoch: {epoch:02d}, Loss: {tr_loss:.4f}, Val: {va_loss:.4f}, '
          f'Test: {te_loss:.4f}')
    if va_loss < best_validation_loss:
        best_epoch = epoch
        best_validation_loss = va_loss
        test_set_mae = te_loss
        
print("\nModel's performance on the test set\n"
        "===================================\n"
        f'MAE={test_set_mae}\n'
        f'Epoch={best_epoch}')
# Out:
# OptimizedModule(
#   (_orig_mod): GraphTransformerNet(
#     (node_emb): Linear(in_features=76, out_features=128, bias=False)
#     (edge_emb): Linear(in_features=10, out_features=128, bias=False)
#     (pe_emb): Linear(in_features=6, out_features=128, bias=False)
#     (gt_layers): ModuleList(
#       (0-3): 4 x GTConv(128, 128, heads=8, aggrs: sum,mean, qkv_bias: False, gate: False)
#     )
#     (global_pool): MultiAggregation([
#       SumAggregation(),
#       MeanAggregation(),
#       MaxAggregation(),
#       StdAggregation(),
#     ], mode=cat)
#     (mu_mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#     (log_var_mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )
# Number of params: 871 k
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] WON'T CONVERT forward /home/marcelo/.local/lib/python3.8/site-packages/torch_geometric/nn/aggr/basic.py line 33
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] due to:
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1098, in compile_subgraph
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 461, in aot_dispatch_autograd
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1640, in codegen
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.scheduler.codegen()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/scheduler.py", line 2741, in codegen
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.get_backend(device).codegen_node(node)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/cuda_combined_scheduling.py", line 69, in codegen_node
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self._triton_scheduling.codegen_node(node)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1148, in codegen_node
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.codegen_node_schedule(node_schedule, buf_accesses, numel, rnumel)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1317, in codegen_node_schedule
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     src_code = kernel.codegen_kernel()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2159, in codegen_kernel
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     **self.inductor_meta_common(),
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2047, in inductor_meta_common
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     "backend_hash": torch.utils._triton.triton_hash_with_backend(),
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/utils/_triton.py", line 61, in triton_hash_with_backend
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1098, in compile_subgraph
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 1951, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 461, in aot_dispatch_autograd
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.8/contextlib.py", line 75, in inner
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/graph.py", line 1640, in codegen
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.scheduler.codegen()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/scheduler.py", line 2741, in codegen
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     self.get_backend(device).codegen_node(node)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/cuda_combined_scheduling.py", line 69, in codegen_node
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self._triton_scheduling.codegen_node(node)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1148, in codegen_node
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     return self.codegen_node_schedule(node_schedule, buf_accesses, numel, rnumel)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/simd.py", line 1317, in codegen_node_schedule
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     src_code = kernel.codegen_kernel()
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2159, in codegen_kernel
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     **self.inductor_meta_common(),
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/_inductor/codegen/triton.py", line 2047, in inductor_meta_common
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     "backend_hash": torch.utils._triton.triton_hash_with_backend(),
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.8/dist-packages/torch/utils/_triton.py", line 61, in triton_hash_with_backend
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]     from triton.compiler.compiler import triton_key
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] ImportError: cannot import name 'triton_key' from 'triton.compiler.compiler' (/usr/local/lib/python3.8/dist-packages/triton/compiler/compiler.py)
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1008 10:22:28.975227 140382441187136 torch/_dynamo/convert_frame.py:1009]
# Epoch: 01, Loss: 1.1644, Val: 1.0854, Test: 1.1061
# Epoch: 02, Loss: 0.9733, Val: 1.1846, Test: 1.2481
# Epoch: 03, Loss: 0.9463, Val: 1.1183, Test: 1.2172
# Epoch: 04, Loss: 0.9356, Val: 1.0477, Test: 1.0700
# Epoch: 05, Loss: 0.8883, Val: 1.0379, Test: 1.0295
# Epoch: 06, Loss: 0.8955, Val: 0.9915, Test: 1.0146
# Epoch: 07, Loss: 0.8557, Val: 1.0464, Test: 1.1427
# Epoch: 08, Loss: 0.8233, Val: 0.8565, Test: 0.8701
# Epoch: 09, Loss: 0.7962, Val: 0.9420, Test: 0.9827
# Epoch: 10, Loss: 0.7905, Val: 1.6679, Test: 1.7724
# Epoch: 11, Loss: 0.7843, Val: 0.9867, Test: 0.9551
# Epoch: 12, Loss: 0.7589, Val: 1.4355, Test: 1.5197
# Epoch: 13, Loss: 0.7326, Val: 0.7995, Test: 0.8153
# Epoch: 14, Loss: 0.7201, Val: 0.8180, Test: 0.8312
# Epoch: 15, Loss: 0.6840, Val: 0.6959, Test: 0.7463
# Epoch: 16, Loss: 0.6687, Val: 1.1551, Test: 1.2408
# Epoch: 17, Loss: 0.6668, Val: 1.3269, Test: 1.4975
# Epoch: 18, Loss: 0.6486, Val: 0.8942, Test: 1.0254
# Epoch: 19, Loss: 0.6396, Val: 0.6696, Test: 0.7344
# Epoch: 20, Loss: 0.6092, Val: 0.8037, Test: 0.8064
# Epoch: 21, Loss: 0.6187, Val: 0.7888, Test: 0.9012
# Epoch: 22, Loss: 0.5767, Val: 0.7538, Test: 0.8669
# Epoch: 23, Loss: 0.5866, Val: 0.8763, Test: 0.9455
# Epoch: 24, Loss: 0.5873, Val: 0.8908, Test: 0.9900
# Epoch: 25, Loss: 0.5873, Val: 0.9043, Test: 0.9771
# Epoch: 26, Loss: 0.5709, Val: 0.9579, Test: 0.9394
# Epoch: 27, Loss: 0.5503, Val: 1.0158, Test: 1.1828
# Epoch: 28, Loss: 0.5437, Val: 0.9144, Test: 1.0293
# Epoch: 29, Loss: 0.5334, Val: 1.2335, Test: 1.2903
# Epoch: 30, Loss: 0.5354, Val: 0.8321, Test: 0.9438
# Epoch: 31, Loss: 0.5107, Val: 0.6844, Test: 0.7967
# Epoch: 32, Loss: 0.4902, Val: 1.1427, Test: 1.2698
# Epoch: 33, Loss: 0.4721, Val: 0.8652, Test: 0.9826
# Epoch: 34, Loss: 0.4659, Val: 1.2040, Test: 1.3168
# Epoch: 35, Loss: 0.4505, Val: 0.9355, Test: 1.0542
# Epoch: 36, Loss: 0.4369, Val: 0.8753, Test: 0.9852
# Epoch: 37, Loss: 0.4433, Val: 0.8359, Test: 0.9638
# Epoch: 38, Loss: 0.4438, Val: 0.5705, Test: 0.6365
# Epoch: 39, Loss: 0.4389, Val: 0.5948, Test: 0.6379
# Epoch: 40, Loss: 0.4396, Val: 0.8907, Test: 0.9979
# Epoch: 41, Loss: 0.4227, Val: 0.5421, Test: 0.5778
# Epoch: 42, Loss: 0.4162, Val: 0.6324, Test: 0.7000
# Epoch: 43, Loss: 0.4209, Val: 0.5470, Test: 0.5976
# Epoch: 44, Loss: 0.4185, Val: 0.8705, Test: 0.8656
# Epoch: 45, Loss: 0.4177, Val: 0.8259, Test: 0.9045
# Epoch: 46, Loss: 0.4178, Val: 0.6003, Test: 0.6560
# Epoch: 47, Loss: 0.3989, Val: 0.7056, Test: 0.7736
# Epoch: 48, Loss: 0.3977, Val: 0.6017, Test: 0.6713
# Epoch: 49, Loss: 0.3961, Val: 0.6117, Test: 0.6392
# Epoch: 50, Loss: 0.3953, Val: 0.5722, Test: 0.5986
#
# Model's performance on the test set
# ===================================
# MAE=0.5778326392173767
# Epoch=41
