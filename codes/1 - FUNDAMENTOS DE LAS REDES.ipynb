# %% [markdown]
# # IIC-3641 GML UC

# %% [markdown]
# - Versiones de librerías, python 3.10.2
#
# - networkx 2.6.2

# %% [markdown]
# # Grafos no dirigidos

# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node(4)
G.add_edge(1, 4)

# %%
G.number_of_nodes()
# Out:
# 4

# %%
G.number_of_edges()
# Out:
# 3

# %%
import matplotlib.pyplot as plt

nx.draw(G, with_labels=True, font_weight='bold')

# %%
G.remove_node(2)

# %% [markdown]
# # Grafos dirigidos

# %%
DG = nx.DiGraph()
DG.add_edge(2, 1)   
DG.add_edge(1, 3)
DG.add_edge(2, 4)

# %%
nx.draw(DG, with_labels=True, font_weight='bold')

# %% [markdown]
# # Nodos con atributos

# %%
G.add_node(1, time='5pm')
G.add_nodes_from([3], time='2pm')
G.nodes[1]
# Out:
# {'time': '5pm'}

# %% [markdown]
# # Enlaces con atributos

# %%
G.add_edge(1, 2, weight=4.7 )
G.add_edges_from([(3, 4), (4, 5)], color='red')
G.add_edges_from([(1, 2, {'color': 'blue'}), (2, 3, {'weight': 8})])
G[1][2]['weight'] = 4.7
G.edges[3, 4]['weight'] = 4.2

# %% [markdown]
# # Multigrafos

# %%
MG = nx.MultiGraph()
MG.add_weighted_edges_from([(1, 2, 0.5), (1, 2, 0.75), (2, 3, 0.5)])

# %% [markdown]
# # Operadores

# %%
G = nx.Graph([(0, 1), (0, 2), (1, 2)])
H = nx.Graph([(3, 4), (3, 5), (4, 5), (4, 6)])
U = nx.union(G, H, rename=("G", "H"))

# %%
nx.draw(U, with_labels=True, font_weight='bold')

# %%
U.add_edge('G1', 'H6')

# %%
nx.draw(U, with_labels=True, font_weight='bold')

# %%
G = nx.Graph([(0, 1), (0, 2)])
H = nx.Graph([(0, 1), (1, 2)])
R = nx.compose(G, H)

# %%
nx.draw(R, with_labels=True, font_weight='bold')

# %%
G = nx.Graph([(1, 2), (1, 3), (2, 3), (3, 4), (3, 5)])
G_complement = nx.complement(G)

# %%
nx.draw(G, with_labels=True, font_weight='bold')

# %%
nx.draw(G_complement, with_labels=True, font_weight='bold')

# %% [markdown]
# # Random networks

# %%
er = nx.erdos_renyi_graph(100, 0.15)

# %%
nx.draw(er, with_labels=True, font_weight='bold')

# %% [markdown]
# # Métricas

# %%
nx.clustering(er)
# Out:
# {0: 0.1111111111111111,
#  1: 0.23636363636363636,
#  2: 0.0989010989010989,
#  3: 0.11764705882352941,
#  4: 0.17582417582417584,
#  5: 0.11029411764705882,
#  6: 0.17777777777777778,
#  7: 0.11666666666666667,
#  8: 0.16666666666666666,
#  9: 0.11666666666666667,
#  10: 0.0989010989010989,
#  11: 0.1437908496732026,
#  12: 0.08571428571428572,
#  13: 0.11029411764705882,
#  14: 0.1437908496732026,
#  15: 0.14619883040935672,
#  16: 0.09090909090909091,
#  17: 0.17857142857142858,
#  18: 0.1523809523809524,
#  19: 0.13333333333333333,
#  20: 0.09090909090909091,
#  21: 0.13333333333333333,
#  22: 0.15384615384615385,
#  23: 0.1523809523809524,
#  24: 0.17777777777777778,
#  25: 0.15,
#  26: 0.10476190476190476,
#  27: 0.10606060606060606,
#  28: 0.2,
#  29: 0.16666666666666666,
#  30: 0.10833333333333334,
#  31: 0.13636363636363635,
#  32: 0.1978021978021978,
#  33: 0.21666666666666667,
#  34: 0.1871345029239766,
#  35: 0.14285714285714285,
#  36: 0.1523809523809524,
#  37: 0.15263157894736842,
#  38: 0.1368421052631579,
#  39: 0.07142857142857142,
#  40: 0.19047619047619047,
#  41: 0.15441176470588236,
#  42: 0.12380952380952381,
#  43: 0.19444444444444445,
#  44: 0.15,
#  45: 0.15,
#  46: 0.1503267973856209,
#  47: 0.1794871794871795,
#  48: 0.17857142857142858,
#  49: 0.16374269005847952,
#  50: 0.22727272727272727,
#  51: 0.11764705882352941,
#  52: 0.0718954248366013,
#  53: 0.14166666666666666,
#  54: 0.13333333333333333,
#  55: 0.16666666666666666,
#  56: 0.13333333333333333,
#  57: 0.2545454545454545,
#  58: 0.21212121212121213,
#  59: 0.18095238095238095,
#  60: 0.15151515151515152,
#  61: 0.2,
#  62: 0.17777777777777778,
#  63: 0.1794871794871795,
#  64: 0.13636363636363635,
#  65: 0.1645021645021645,
#  66: 0.14166666666666666,
#  67: 0.2,
#  68: 0.26666666666666666,
#  69: 0.18181818181818182,
#  70: 0.17142857142857143,
#  71: 0.16374269005847952,
#  72: 0.13333333333333333,
#  73: 0.1111111111111111,
#  74: 0.13333333333333333,
#  75: 0.125,
#  76: 0.09090909090909091,
#  77: 0.10606060606060606,
#  78: 0.15151515151515152,
#  79: 0.14736842105263157,
#  80: 0.16363636363636364,
#  81: 0.08791208791208792,
#  82: 0.10989010989010989,
#  83: 0.13333333333333333,
#  84: 0.1695906432748538,
#  85: 0.11538461538461539,
#  86: 0.13333333333333333,
#  87: 0.14285714285714285,
#  88: 0.17647058823529413,
#  89: 0.20915032679738563,
#  90: 0.1388888888888889,
#  91: 0.047619047619047616,
#  92: 0.16363636363636364,
#  93: 0.21978021978021978,
#  94: 0.25,
#  95: 0.18181818181818182,
#  96: 0.14736842105263157,
#  97: 0.1111111111111111,
#  98: 0.1368421052631579,
#  99: 0.1631578947368421}

# %%
er.degree()
# Out:
# DegreeView({0: 18, 1: 11, 2: 14, 3: 17, 4: 14, 5: 17, 6: 10, 7: 16, 8: 12, 9: 16, 10: 14, 11: 18, 12: 15, 13: 17, 14: 18, 15: 19, 16: 12, 17: 8, 18: 15, 19: 16, 20: 12, 21: 15, 22: 13, 23: 15, 24: 10, 25: 16, 26: 15, 27: 12, 28: 16, 29: 13, 30: 16, 31: 12, 32: 14, 33: 16, 34: 19, 35: 22, 36: 15, 37: 20, 38: 20, 39: 8, 40: 15, 41: 17, 42: 21, 43: 9, 44: 16, 45: 25, 46: 18, 47: 13, 48: 8, 49: 19, 50: 12, 51: 17, 52: 18, 53: 16, 54: 10, 55: 16, 56: 10, 57: 11, 58: 12, 59: 15, 60: 12, 61: 11, 62: 10, 63: 13, 64: 12, 65: 22, 66: 16, 67: 11, 68: 10, 69: 11, 70: 15, 71: 19, 72: 15, 73: 18, 74: 21, 75: 17, 76: 11, 77: 12, 78: 12, 79: 20, 80: 11, 81: 14, 82: 14, 83: 10, 84: 19, 85: 13, 86: 10, 87: 14, 88: 17, 89: 18, 90: 9, 91: 7, 92: 11, 93: 14, 94: 8, 95: 12, 96: 20, 97: 19, 98: 20, 99: 20})

# %%
nx.diameter(er)
# Out:
# 3

# %% [markdown]
# # Distribución de grado

# %%
G = nx.erdos_renyi_graph(10000, 0.1)

degrees = [G.degree(n) for n in G.nodes()]

degree_counts = {}
for degree in degrees:
    if degree in degree_counts:
        degree_counts[degree] += 1
    else:
        degree_counts[degree] = 1

sorted_degrees = sorted(degree_counts.items())

x, y = zip(*sorted_degrees)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'bo-', markersize=8)
plt.title('Distribución de Grado')
plt.xlabel('Grado')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
